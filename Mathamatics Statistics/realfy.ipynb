# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# data = yf.download('SPY', start='2023-01-01',end='2023-12-31')

# %%
# data['Daily Return'] = data['Close'].pct_change() #pct_change = percentage change after closing the price
# returns = data['Daily Return'].dropna()

# %%
# arithmetic_mean = returns.mean()
# print(f"Arithmatic mean return : {round(arithmetic_mean * 100, 4)}%")
# Out:
# Arithmatic mean return : 0.0985%

# %%
# def geomatric_mean(returns):
#     returns = [1 + r for r in returns]
    
#     product = np.prod(returns)
#     gm = product ** (1/len(returns)) - 1
#     return gm

# geomatric_mean_return = geomatric_mean(returns)
# print(f"Geomatric Mean Return: {round(geomatric_mean_return * 100,4)}%")
# Out:
# Geomatric Mean Return: 0.0951%

# %%
# symbol = 'QQQ'

# data = yf.download(symbol,start='2023-01-01',end='2023-12-31')

# data['Daily Return'] = data['Close'].pct_change()
# returns = data['Daily Return'].dropna()
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_9416\4288154265.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol,start='2023-01-01',end='2023-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
# arithmetic_mean = returns.mean()
# print(f"Arithmetic mean:{round(arithmetic_mean * 100,4)}%")


# def geomatric_mean(returns):
#     returns =[1 + r for r in returns]
#     product = np.prod(returns)
#     gm = product ** (1/len(returns)) - 1
#     return gm

# geometric_mean_return = geomatric_mean(returns)
# print(f"Geometric mean:{round(geometric_mean_return * 100,4)}%")
# Out:
# Arithmetic mean:0.1848%
# Geometric mean:0.1785%

# %%
# # Simulate growth from $100 investment
# cumulative_arith = (1 + arithmetic_mean) ** np.arange(len(returns)) * 100
# cumulative_geom = (1 + geometric_mean_return) ** np.arange(len(returns)) * 100

# plt.figure(figsize=(10, 6))
# plt.plot(cumulative_arith, label='Arithmetic Mean Growth', linestyle='--')
# plt.plot(cumulative_geom, label='Geometric Mean Growth', linestyle='-')
# plt.title(f'Cumulative Growth Comparison: {symbol}')
# plt.xlabel('Days')
# plt.ylabel('Portfolio Value ($)')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
# symbol2 = 'VTI'
# data2 = yf.download(symbol2,start='2023-01-01',end='2023-12-31')
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_9416\1244321893.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data2 = yf.download(symbol2,start='2023-01-01',end='2023-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
# data2['Daily Return'] = data2['Close'].pct_change()
# returns2 = data2['Daily Return'].dropna()

# %%
# Arithmeitic_mean_VTI = returns2.mean()

# def geomatric_mean2(returns2):
#     returns2 =[1 + r for r in returns2]
#     product = np.prod(returns2)
#     gm = product ** (1/len(returns2)) - 1
#     return gm

# geomatric_mean_VTI = geomatric_mean2(returns2)

# print(f"Geomatric Mean For VTI:{round(geomatric_mean_VTI * 100,4)}%")
# print(f"Arithmetic Mean For VTI:{round(Arithmeitic_mean_VTI * 100,4)}%")
# Out:
# Geomatric Mean For VTI:0.0947%
# Arithmetic Mean For VTI:0.0983%

# %%
# # Simulate growth from $100 investment
# cumulative_arith = (1 + arithmetic_mean) ** np.arange(len(returns)) * 100
# cumulative_geom = (1 + geometric_mean_return) ** np.arange(len(returns)) * 100

# plt.figure(figsize=(10, 6))
# plt.plot(cumulative_arith, label='Arithmetic Mean Growth', linestyle='--')
# plt.plot(cumulative_geom, label='Geometric Mean Growth', linestyle='-')
# plt.title(f'Cumulative Growth Comparison: {symbol}')
# plt.xlabel('Days')
# plt.ylabel('Portfolio Value ($)')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
# cumulative_arith_VTIs = (1 + Arithmeitic_mean_VTI) ** np.arange(len(returns2)) * 100
# cumulative_geom_VTIs = (1 + geomatric_mean_VTI) ** np.arange(len(returns2)) * 100

# plt.figure(figsize=(10,6))
# plt.plot(cumulative_arith_VTIs, label='Arithmetic Mean Growth', linestyle ='--')
# plt.plot(cumulative_geom_VTIs,label='Geomatric Mean Growth', linestyle='-')
# plt.title(f'Cumulative Growth Comparison: {symbol2}')
# plt.xlabel('Days')
# plt.ylabel('Portfolio Value ($)')
# plt.legend()
# plt.grid(True)
# plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# symbols = ['BTC-USD','BND']
# start_date = '2023-01-01'
# end_date = '2023-12-31'

# BTC = yf.download('BTC-USD', start_date,end_date)
# BND = yf.download('BND', start_date,end_date)

# BTC['Daily Return'] = BTC['Close'].pct_change()
# BND['Daily Return'] = BND['Close'].pct_change()

# BTC_returns_ = BTC['Daily Return'].dropna()
# BND_returns_= BND['Daily Return'].dropna()
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_15408\866735413.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BTC = yf.download('BTC-USD', start_date,end_date)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_15408\866735413.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BND = yf.download('BND', start_date,end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
# BTC_returns = BTC_returns_
# BND_returns = BND_returns_

# def arithmetic_mean(returns):
#     Arithmetic_mean = returns.mean()
#     return Arithmetic_mean

# def geomatric_mean(returns):
#     returns = [1 + r for r in returns]
#     product = np.prod(returns)
#     gm = product ** (1/len(returns)) - 1
#     return gm

# BTC_Arithmetic_mean = arithmetic_mean(BTC_returns)
# BTC_Geomatric_mean = geomatric_mean(BTC_returns)

# BND_Arithmetic_mean = arithmetic_mean(BND_returns)
# BND_Geomatric_mean = geomatric_mean(BND_returns)

# %%
# print(f"BTC Arithmetic mean:{round(BTC_Arithmetic_mean*100,6)}%")
# print(f"BTC Geomatric mean:{round(BTC_Geomatric_mean*100,6)}%")
# print(f"BND Arithmetic mean:{round(BND_Arithmetic_mean*100,6)}%")
# print(f"BND Geomatric mean:{round(BND_Geomatric_mean*100,6)}%")
# Out:
# BTC Arithmetic mean:0.282598%
# BTC Geomatric mean:0.256661%
# BND Arithmetic mean:0.021036%
# BND Geomatric mean:0.019973%

# %%
# symbols = ['BTC-USD', 'BND']
# start_date = '2023-01-01'
# end_date = '2023-12-31'

# df = pd.DataFrame()
# for symbol in symbols:
#     df[symbol] = yf.download(symbol, start=start_date, end=end_date)['Close']

# # Step 2: Calculate daily returns
# returns = df.pct_change().dropna()

# def geometric_mean(r):
#     return (np.prod(1 + r))**(1 / len(r)) - 1

# # Step 4: Compute means
# for symbol in symbols:
#     arith = returns[symbol].mean()
#     geom = geometric_mean(returns[symbol])
#     print(f"{symbol} → Arithmetic Mean: {round(arith * 100, 4)}% | Geometric Mean: {round(geom * 100, 4)}%")
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_15408\3786839312.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df[symbol] = yf.download(symbol, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_15408\3786839312.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df[symbol] = yf.download(symbol, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  1 of 1 completed
# BTC-USD → Arithmetic Mean: 0.2833% | Geometric Mean: 0.2572%
# BND → Arithmetic Mean: 0.0145% | Geometric Mean: 0.0138%
# ...

# %%
# symbols = ['BTC-USD','BND']
# start_date = '2023-01-01'
# end_date = '2023-12-31'

# df = pd.DataFrame()
# for symbol in symbols:
#     df[symbol] = yf.download(symbol,start=start_date,end=end_date)['Close']

# returns = df.pct_change().dropna()

# def geometric_mean(r):
#     return (np.prod(1+r)) ** (1/len(r)) - 1

# print("Mean Return Comparisn (2023)\n")
# for symbol in symbols:
#     arith = returns[symbol].mean()
#     geom = geometric_mean(returns[symbol])
#     print(f"{symbol}: Arithmetic Mean : {round(arith * 100 , 4)}% | Geometric mean : {round(geom * 100 , 4)}%")
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_23740\4270020789.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df[symbol] = yf.download(symbol,start=start_date,end=end_date)['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_23740\4270020789.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df[symbol] = yf.download(symbol,start=start_date,end=end_date)['Close']
# [*********************100%***********************]  1 of 1 completed
# Mean Return Comparisn (2023)
#
# BTC-USD: Arithmetic Mean : 0.2833% | Geometric mean : 0.2572%
# BND: Arithmetic Mean : 0.0145% | Geometric mean : 0.0138%
# ...

# %%
# import matplotlib.pyplot as plt

# # Step 1: Your full Python code as a multiline string
# import yfinance as yf
# import numpy as np
# import pandas as pd

# start_date = '2023-01-01'
# end_date = '2023-12-31'

# BTC = yf.download('BTC-USD', start=start_date, end=end_date)
# BND = yf.download('BND', start=start_date, end=end_date)

# BTC['Daily Return'] = BTC['Close'].pct_change()
# BND['Daily Return'] = BND['Close'].pct_change()

# BTC_returns = BTC['Daily Return'].dropna()
# BND_returns = BND['Daily Return'].dropna()

# def arithmetic_mean(returns):
#     return returns.mean()

# def geometric_mean(returns):
#     returns = 1 + np.array(returns)
#     return np.prod(returns) ** (1 / len(returns)) - 1

# BTC_arith = arithmetic_mean(BTC_returns)
# BTC_geom = geometric_mean(BTC_returns)
# BND_arith = arithmetic_mean(BND_returns)
# BND_geom = geometric_mean(BND_returns)

# print(f"BTC Arithmetic Mean: {round(BTC_arith * 100, 6)}%")
# print(f"BTC Geometric Mean: {round(BTC_geom * 100, 6)}%")
# print(f"BND Arithmetic Mean: {round(BND_arith * 100, 6)}%")
# print(f"BND Geometric Mean: {round(BND_geom * 100, 6)}%")
# Out:
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_23740\4123258738.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BTC = yf.download('BTC-USD', start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\heman_q\AppData\Local\Temp\ipykernel_23740\4123258738.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BND = yf.download('BND', start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# BTC Arithmetic Mean: 0.282598%
# BTC Geometric Mean: 0.256661%
# BND Arithmetic Mean: 0.021036%
# BND Geometric Mean: 0.019973%

# %%
# Harmonic mena

# def harmonic_mean(values):
#     values = np.array(values)
#     return len(values) / np.sum(1 / values)

# pe_ratios = [12.5,10.0,20.0,18.2]
# hm = harmonic_mean(pe_ratios)

# print(f"Harmonic Mean of P/E ratios : {round(hm,4)}")
# Out:
# Harmonic Mean of P/E ratios : 14.0378

# %%
# # Harmonci mean

# def harmonic_mean(values):
#     values = np.array(values)
#     return len(values) / np.sum(1/values)

# pe_ratios = [25.0,15.0,30.0,22.0]
# hm = harmonic_mean(pe_ratios)

# print(f"Harmonic Mean of P/E ratios: {round(hm,4)}")
# Out:
# Harmonic Mean of P/E ratios: 21.5686

# %%
# data = np.array([10, 25, 60, 200])

# arithmetic = np.mean(data)
# geomatric = np.prod(data) ** (1/len(data))
# harmonic = len(data) / np.sum(1/data)

# print(f"Arithmetic Mean: {round(arithmetic ,4)}")
# print(f"Geometric Mean: {round(geomatric,4)}")
# print(f"Harmonic Mean : {round(harmonic,4)}")
# Out:
# Arithmetic Mean: 73.75
# Geometric Mean: 41.6179
# Harmonic Mean : 24.7423

# %%
# from scipy.stats import hmean
# # pe_ratios = np.array([31.76,162.16,27.25])

# # arithmetic_mean = np.mean(pe_ratios)
# # harmonic_mean = len(pe_ratios) / np.sum(1/pe_ratios)
# # harmonic_mean2 = hmean(pe_ratios)
# # print(f"Arithmetic Mean: {round(arithmetic_mean,2)}")
# # print(f"Harmonic Mean : {round(harmonic_mean,2)}")
# # print(f"Harmonic Mean 2 : {round(harmonic_mean2,2)}")

# %%
import matplotlib.pyplot as plt
from scipy.stats import hmean

# data = [31.76,162.16,27.25]

# arithmetic = np.mean(data)
# geomatric = np.prod(data) ** (1/len(data))
# harmonic = hmean(data)

# lables = ['Arithmetic Mean', 'Geomatric Mean', 'Harmonic Mean']
# values = [arithmetic, geomatric, harmonic]

# plt.Figure(figsize=(8, 5))
# bars = plt.bar(lables, values, color=['skyblue','lightgreen','salmon'])

# for bar in bars:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2, yval+1,f'{yval:.2f}',ha='center',fontsize = 10)

# plt.title('Comparison of Arithmetic, Geometric, and Harmonic Means')
# plt.ylabel('Mean values')
# plt.grid(axis='y',linestyle='--',alpha=0.7)
# plt.tight_layout()
# plt.show()

# %%
# distances = [60,90,150]
# efficiencies = [15,20,12]

# fuel_used = sum(d / e for d,e in zip(distances, efficiencies))

# total_distance = sum(distances)
# avg_efficiency = total_distance/fuel_used
# print(f"Average fuek Efficiency: {round(avg_efficiency,2)} km/l")



# lables = ['Segment A','Segment B','Segment C']
# colors = ['skyblue','lightgreen','salmon']

# plt.figure(figsize=(8,5))
# plt.bar(lables,efficiencies,color=colors)
# plt.axhline(avg_efficiency,color = 'purple',linestyle='--',label=f'Weighted Harmonic Mean : {round(avg_efficiency,2)}km/l')
# plt.title('Fuel Efficiency by Segment vs. Journey Average')
# plt.ylabel('Efficiency (km/l)')
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# Average fuek Efficiency: 14.29 km/l

# %%
# rates = [0.10,0.12,0.15]
# durations = [1,2,3]

# numarator = sum(durations)
# denomenator = sum(d/r for d,r in zip(durations,rates))
# harmonic_mean_rate = numarator/denomenator
# print(f"Weighted Harmonic Harmonic Mean Interest Rate: {round(harmonic_mean_rate * 100,2)}%")

# %%
# labels = ['Loan A','Loan B','Loan C']
# colors = ['skyblue','lightgreen','salmon']

# plt.figure(figsize=(8,5))
# plt.bar(labels, [r * 100 for r in rates], color = colors)
# plt.axhline(harmonic_mean_rate * 100,color = 'purple',linestyle='--',
#             label = f'Harmonic Mean: {round(harmonic_mean_rate * 100, 2)}%')

# plt.title('Interest Rates Across Loans vs. Harmonic Mean')
# plt.ylabel('Interest Rate (%)')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# lables = ['Loan A','Loan B','Loan C']
# colors = ['skyblue','lightgreen','salmon']

# plt.figure(figsize=(8,5))
# plt.bar(lables, [r * 100 for r in rates] , color = colors)
# plt.axhline(harmonic_mean_rate * 100 , color = 'purple',linestyle='--',
#             label = f'Harmonic Mean: {round(harmonic_mean_rate * 100, 2)}%')

# plt.title('Interest Rates Across Loans vs. Harmonic Mean')
# plt.ylabel('Interest Rates Across Loans vs. Harmonic Mean')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# rates = [0.10,0.12,0.15]
# durations = [1,2,3]

# numarator = sum(durations)
# denomenator = sum(d/r for d,r in zip(durations,rates))
# harmonic_mean_rate = numarator/denomenator
# print(round(harmonic_mean_rate * 100,2))
# Out:
# 12.86
